# %%
#!/usr/bin/env python3
import pandas as pd, plspm.config as c
from plspm.plspm import Plspm
from plspm.scheme import Scheme
from plspm.mode import Mode

satisfaction = pd.read_csv("satisfaction.csv", index_col=0)

structure = c.Structure()
structure.add_path(["IMAG"], ["EXPE", "SAT", "LOY"])
structure.add_path(["EXPE"], ["QUAL", "VAL", "SAT"])
structure.add_path(["QUAL"], ["VAL", "SAT"])
structure.add_path(["VAL"], ["SAT"])
structure.add_path(["SAT"], ["LOY"])

config = c.Config(structure.path(), scaled=False)
config.add_lv_with_columns_named("IMAG", Mode.A, satisfaction, "imag")
config.add_lv_with_columns_named("EXPE", Mode.A, satisfaction, "expe")
config.add_lv_with_columns_named("QUAL", Mode.A, satisfaction, "qual")
config.add_lv_with_columns_named("VAL", Mode.A, satisfaction, "val")
config.add_lv_with_columns_named("SAT", Mode.A, satisfaction, "sat")
config.add_lv_with_columns_named("LOY", Mode.A, satisfaction, "loy")

plspm_calc = Plspm(satisfaction, config, Scheme.CENTROID)
print(plspm_calc.inner_summary())
print(plspm_calc.path_coefficients())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2692\689292150.py in ?()
#      20 config.add_lv_with_columns_named("VAL", Mode.A, satisfaction, "val")
#      21 config.add_lv_with_columns_named("SAT", Mode.A, satisfaction, "sat")
#      22 config.add_lv_with_columns_named("LOY", Mode.A, satisfaction, "loy")
#      23
# ---> 24 plspm_calc = Plspm(satisfaction, config, Scheme.CENTROID)
#      25 print(plspm_calc.inner_summary())
#      26 print(plspm_calc.path_coefficients())
#
# c:\Users\patri\AppData\Local\Programs\Python\Python311\Lib\site-packages\plspm\plspm.py in ?(self, data, config, scheme, iterations, tolerance, bootstrap, bootstrap_iterations, processes)
#      67         calculator = w.WeightsCalculatorFactory(config, iterations, tolerance, correction, scheme)
#      68         final_data, scores, weights = estimator.estimate(calculator, filtered_data)
#      69         config = estimator.config()
#      70
# ---> 71         self.__inner_model = im.InnerModel(config.path(), scores)
#      72         self.__outer_model = om.OuterModel(final_data, scores, weights, config.odm(config.path()), self.__inner_model.r_squared())
#      73         self.__inner_summary = pis.InnerSummary(config, self.__inner_model.r_squared(),
#      74                                                 self.__inner_model.r_squared_adj(), self.__outer_model.model())
#
# c:\Users\patri\AppData\Local\Programs\Python\Python311\Lib\site-packages\plspm\inner_model.py in ?(self, path, scores)
#      70             self.__path_coefficients.loc[dv, ivs] = regression.params
#      71             rsquared = regression.rsquared
#      72             self.__r_squared.loc[dv] = rsquared
#      73             self.__r_squared_adj.loc[dv] = 1 - (1 - rsquared) * (rows - 1) / (rows - path.loc[dv].sum() - 1)
# ---> 74             self.__summaries = self.__summaries.append(_summary(dv, regression)).reset_index(drop=True)
#      75         self.__effects = _effects(self.__path_coefficients)
#
# c:\Users\patri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
satisfaction
# Out:
#      imag1  imag2  imag3  imag4  imag5  expe1  expe2  expe3  expe4  expe5  \
# 1        8      8      9      5      6      9      9      5      8      9
# 2        9      9     10      9      7      9      8     10      8      9
# 3        9      8      8      8      8      8      8      8      9      9
# 4        8      9      8      9      7     10      6      3     10     10
# 5       10     10      8     10      8      7      9      8      9      8
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 246      9      9      9      9      8      6      7      5      8      5
# 247      8      9      9      7      8      9      8      7      7      9
# 248      8      8      8      8      8      8      7      7      7      3
# 249      8      9      9      4      8      5     10      7      7      7
# 250     10      9      7      7      9      8      6      4      7      7
#
#      ...  val4  sat1  sat2  sat3  sat4  loy1  loy2  loy3  loy4  gender
# 1    ...     6     6     7     6     7     9     9     6     6    male
# 2    ...     8     8     7     8     7     8     9     8     8  female
# 3    ...     8     9     8     8     8     9     8     9     9  female
# 4    ...     4     7     7     7     6     6     6     5     5    male
# 5    ...     8     8     8     8     7     8     9     9     9  female
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...     ...
# 246  ...     8     8     8     8     7     7     6     8     8  female
# 247  ...     8     7     6     7     8     3     5     3     6  female
# 248  ...     8     8     7     8     6     8     2     8     7    male
# 249  ...     7     9     7     8     7     6     7     8     6    male
# 250  ...     8     7     7     7     6     8     7     5     7    male
#
# [250 rows x 28 columns]
